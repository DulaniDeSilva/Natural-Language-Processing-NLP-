# %% [markdown]
# # AG_News_Dataset: 4 Class indexes 1- world, 3-sprots, 3-business, 4-Sci/tech
# ## Titles - containes titles of the news articles
# ## Description - Contains description of the news articles
# ## Colab paid products - Cancel contracts here

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("D:\\GITHUB\\Natural-Language-Processing-NLP-\\AGNewsClassification\\train.csv", encoding="utf-8")

# %%
print("Shape of df:", df.shape)
print("Data Types of df:", df.dtypes)
print("First rows of df:", df.head(5))
print("Samples of df:", df.sample(5))
# Out:
# Shape of df: (120000, 3)
# Data Types of df: Class Index     int64
# Title          object
# Description    object
# dtype: object
# First rows of df:    Class Index                                              Title  \
# 0            3  Wall St. Bears Claw Back Into the Black (Reuters)
# 1            3  Carlyle Looks Toward Commercial Aerospace (Reu...
# 2            3    Oil and Economy Cloud Stocks' Outlook (Reuters)
# 3            3  Iraq Halts Oil Exports from Main Southern Pipe...
# 4            3  Oil prices soar to all-time record, posing new...
#
#                                          Description
# 0  Reuters - Short-sellers, Wall Street's dwindli...
# 1  Reuters - Private investment firm Carlyle Grou...
# 2  Reuters - Soaring crude prices plus worries\ab...
# 3  Reuters - Authorities have halted oil export\f...
# 4  AFP - Tearaway world oil prices, toppling reco...
# Samples of df:        Class Index                                              Title  \
# ...

# %%
print(df.describe())
# Out:
#          Class Index
# count  120000.000000
# mean        2.500000
# std         1.118039
# min         1.000000
# 25%         1.750000
# 50%         2.500000
# 75%         3.250000
# max         4.000000

# %%
# string column stats
print(df.describe(include="object"))
# Out:
#                    Title                                        Description
# count             120000                                             120000
# unique            114350                                             118723
# top     Today's schedule  With the economy slowly turning up, upgrading ...
# freq                  39                                                 15

# %%
# missing values
print(df.isnull().sum())
# Out:
# Class Index    0
# Title          0
# Description    0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Text lenght analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import nltk

nltk.downlaod("punkt", quiet =True)

text_col_1 = "Title"
text_col_2 = "Description"

df["char_count"] = df[text_col_1].str.len()
df["word count"] = df[text_col_1].str.split().str.len()
df["sent_count"] = df[text_col_1].apply(lambda x: len(nltk.sent_tokenize(str(x))) if pd.notna(x) else 0
